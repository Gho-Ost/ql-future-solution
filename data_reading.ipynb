# %%
from utils.utils import *

# %%
data1, data2 = read_data(directory = "data//benign")

# %%
data1.shape
# Out:
# (437, 300, 300, 3)

# %%
data2.shape
# Out:
# (437, 300, 300)

# %%
show_image(data1, -1)

# %%
show_image(data2, -1)

# %%
data1, data2 = read_data(directory = "data//malignant")

# %%
show_image(data1, -1)

# %%
show_image(data2, -1)

# %%
print(len(data1))
# Out:
# 210

# %%
print(len(data2))
# Out:
# 210

# %%
data1, data2 = read_data(directory = "data//normal")

# %%
print(len(data1))
# Out:
# 133

# %%
print(len(data2))
# Out:
# 133

# %%
show_image(data1, -1)

# %%
show_image(data2, -1)
